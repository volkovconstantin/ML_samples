# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from numpy.random import randn


fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax1.hist(randn(100), bins=20, color='k',alpha=0.2)
x1=ax1.get_xlim()
ax2=fig.add_subplot(2,2,2)
ax2.scatter(np.arange(30), np.arange(30)+3*randn(30))
x2=ax2.get_xlim()
ax3=fig.add_subplot(2,2,3)
ax3.plot(randn(30),'k--')
x3=ax3.get_xlim()
print(x1, x2, x3)
# Out:
# (-2.6048710350948316, 2.8129758350890413) (-1.4716845878136202, 30.47168458781362) (-1.4500000000000002, 30.449999999999999)

# %%
plt.subplots(2,3,figsize=(8,6),squeeze=False, sharex=True, sharey=True)
# Out:
# (<matplotlib.figure.Figure at 0x89bdbf0>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x08912A90>,
# ...
#          <matplotlib.axes._subplots.AxesSubplot object at 0x086BEB50>]], dtype=object))

# %%
fig, axes=plt.subplots(2,5,figsize=(16,6), sharex=True, sharey=True)
for i in range(2):
    for j in range (5):
        axes[i,j].hist(randn(500), bins=50)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
plt.plot(randn(30).cumsum(), linestyle='dashed', marker='o')

# %%
data=randn(50).cumsum()
plt.plot(data, linestyle='dashed')
plt.plot(data, drawstyle='steps-post', label='steps-post')
plt.xlim([0,20])
# Out:
# (0, 20)

# %%
data=randn(50).cumsum()
plt.plot(data, linestyle='dashed')
plt.plot(data, drawstyle='steps-post', label='steps-post')
plt.xlim([0,20])
# Out:
# (0, 20)

# %%
fig=plt.figure(); ax=fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum())
ticks=ax.set_xticks([0,250,500,750,1000])

# %%
fig=plt.figure(); ax=fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum())
ax.set_xticks([0,250,500,750,1000])
ax.set_xticklabels(['one','two','three', 'four', 'five'], rotation=30)
ax.set_title('First graph')
ax.set_xlabel('Stages')
# Out:
# Text(0.5,0,'Stages')

# %%
plt.plot(randn(100).cumsum(), 'k', label='One')
plt.plot(randn(100).cumsum(), 'k--', label='Two')
plt.plot(randn(100).cumsum(), 'k.--', label='Three')
plt.legend(loc='best') #automatically creates a legend

# %%
# saving a plot to a file
plt.plot(randn(100).cumsum(), 'k',color='b', label='One')
plt.plot(randn(100).cumsum(), 'k--',color='r', label='Two')
plt.plot(randn(100).cumsum(), 'k.--', color='g', label='Three')
plt.legend(loc='best')
plt.savefig(r'C:\Users\Константин\Desktop\figpath.png', dpi=400, bbox_inches='tight')

# %%
plt.plot(randn(100).cumsum(), 'k',color='b', label='One')
plt.plot(randn(100).cumsum(), 'k--',color='r', label='Two')
plt.plot(randn(100).cumsum(), 'k.--', color='g', label='Three')
plt.legend(loc='best')
plt.savefig(r'C:\Users\Константин\Desktop\figpath.pdf', dpi=400, bbox_inches='tight')
